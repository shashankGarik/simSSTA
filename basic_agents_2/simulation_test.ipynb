# %%
# %run test_working.py

# %%
# %run dublins_car_pygame.py

# %%
# %run dublins_car_model.py

# %%
# %run potential_field_test.py

# %%
# %run basic_agent_2.py
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.7.16)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\Welcome\Documents\Kouby\M.S.Robo- Georgia Tech\GATECH LABS\SHREYAS_LAB\Simulation_Environment\Github Simulation Network\basic_agents_2\basic_agent_2.py in <module>
#       3 import numpy as np
#       4 from controllers_2 import *
# ----> 5 from loop_agents_2 import *
#       6 from Environment_2 import Environment
#       7
#
# c:\Users\Welcome\Documents\Kouby\M.S.Robo- Georgia Tech\GATECH LABS\SHREYAS_LAB\Simulation_Environment\Github Simulation Network\basic_agents_2\loop_agents_2.py in <module>
#       2 import random
#       3 import numpy as np
# ----> 4 from controllers import *
#       5 from basic_agent import *
#       6 from itertools import permutations
#
# ...
